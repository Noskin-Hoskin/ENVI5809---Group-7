# %% [markdown]
# # Understanding the relationship(s) between water chemistry variables within and between flood events from the Burdekin River

# %% [markdown]
# **Methods:**
#
# 1. Load in required packages
# 2. Load in master data file
# 3. Long-term variable plots
# 4. 2019 flood event plot

# %% [markdown]
# ## Load in packages

# %%
import pandas as pd

from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16,8)
# %matplotlib inline

# %% [markdown]
# ## Load in master data file

# %%
# Load in df 
df = pd.read_csv(
        "211021_masterdf.csv",
        sep=r",",
        engine="c",
        header=0,
        na_filter=False,
        low_memory=False,
    )
# Adjust time and date column 
df['Aggregated Date/Time']= pd.to_datetime(df['Aggregated Date/Time'])

# %% [markdown]
# Check the dataframe

# %%
df.head()
# Out:
#   Aggregated Date/Time  Depth     Site Name  Latitude  Longitude  omega   pH  \
# 0           2010-12-01   -0.5      Old Reef -19.40350  148.11089    3.0  8.0
# 1           2010-12-01   -0.5    Faith Reef -19.27587  148.34538    3.0  8.0
# 2           2010-12-01   -0.5  Charity reef -19.36723  148.33749    3.0  8.0
# 3           2010-12-01   -0.5     Hope Reef -19.32382  148.43362    3.0  8.0
# 4           2010-12-01   -0.5    Tiger Reef -19.19677  148.54760    3.0  8.0
#
#         salt        chloro
# 0  35.326149  1.000000e-12
# 1  35.356635  1.000000e-12
# 2  35.287498  1.000000e-12
# 3  35.303888  1.828146e-01
# 4  35.360924  2.678836e-01

# %% [markdown]
# Remove spaces in names for easy manipulation

# %%
df.columns = df.columns.str.replace(' ','_')
df.columns = df.columns.str.replace('/','_')

# %% [markdown]
# ## Long-term variable plots

# %% [markdown]
# ### Ω (Aragonite Saturation State)

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df['Site_Name'].unique())
rivermouth = df[(df.Site_Name == "Burdekin river rivermouth")]
offshore = df[(df.Site_Name == "Burdekin river offshore")]
tink = df[(df.Site_Name == "Tink shoal")]
wilson = df[(df.Site_Name == "Wilson Shoal")]
morinda = df[(df.Site_Name == "Morinda Shoal")]
old = df[(df.Site_Name == "Old Reef")]
stanley = df[(df.Site_Name == "Stanley Reef")]
bowden = df[(df.Site_Name == "Bowden Reef")]
darley = df[(df.Site_Name == "Darley Reef")]
broadhurst = df[(df.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df[(df.Site_Name == "Charity reef")]
shell = df[(df.Site_Name == "Shell Reef")]
faith = df[(df.Site_Name == "Faith Reef")]
shrimp = df[(df.Site_Name == "Shrimp Reef")]
hope = df[(df.Site_Name == "Hope Reef")]
UN_19_280 = df[(df.Site_Name == "U/N Reef 19-280")]
viper = df[(df.Site_Name == "Viper Reef")]
UN_18_132 = df[(df.Site_Name == "U/N Reef 18-132")]
tiger = df[(df.Site_Name == "Tiger Reef")]
cup = df[(df.Site_Name == "Cup Reef (North)")]
leopard = df[(df.Site_Name == "Leopard reef")]
jacqueline = df[(df.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'omega', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'omega', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'omega', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'omega', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'omega', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'omega', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'omega', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Aragonite Saturation State (Ω)", size= 15)
plt.title("Long-term Aragonite Saturation State (Ω)", size = 20)

# add horizontal lines for thresholds 
plt.axhline(y=2.82, color='k', linestyle='--', label = 'Ω Threshold: 2.82')


plt.legend(ncol = 3, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ### pH

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df['Site_Name'].unique())
rivermouth = df[(df.Site_Name == "Burdekin river rivermouth")]
offshore = df[(df.Site_Name == "Burdekin river offshore")]
tink = df[(df.Site_Name == "Tink shoal")]
wilson = df[(df.Site_Name == "Wilson Shoal")]
morinda = df[(df.Site_Name == "Morinda Shoal")]
old = df[(df.Site_Name == "Old Reef")]
stanley = df[(df.Site_Name == "Stanley Reef")]
bowden = df[(df.Site_Name == "Bowden Reef")]
darley = df[(df.Site_Name == "Darley Reef")]
broadhurst = df[(df.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df[(df.Site_Name == "Charity reef")]
shell = df[(df.Site_Name == "Shell Reef")]
faith = df[(df.Site_Name == "Faith Reef")]
shrimp = df[(df.Site_Name == "Shrimp Reef")]
hope = df[(df.Site_Name == "Hope Reef")]
UN_19_280 = df[(df.Site_Name == "U/N Reef 19-280")]
viper = df[(df.Site_Name == "Viper Reef")]
UN_18_132 = df[(df.Site_Name == "U/N Reef 18-132")]
tiger = df[(df.Site_Name == "Tiger Reef")]
cup = df[(df.Site_Name == "Cup Reef (North)")]
leopard = df[(df.Site_Name == "Leopard reef")]
jacqueline = df[(df.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'pH', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'pH', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'pH', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'pH', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'pH', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'pH', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'pH', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("pH", size= 15)
plt.title("Long-term pH", size = 20)

plt.legend(ncol = 3, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ### Salinity

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df['Site_Name'].unique())
rivermouth = df[(df.Site_Name == "Burdekin river rivermouth")]
offshore = df[(df.Site_Name == "Burdekin river offshore")]
tink = df[(df.Site_Name == "Tink shoal")]
wilson = df[(df.Site_Name == "Wilson Shoal")]
morinda = df[(df.Site_Name == "Morinda Shoal")]
old = df[(df.Site_Name == "Old Reef")]
stanley = df[(df.Site_Name == "Stanley Reef")]
bowden = df[(df.Site_Name == "Bowden Reef")]
darley = df[(df.Site_Name == "Darley Reef")]
broadhurst = df[(df.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df[(df.Site_Name == "Charity reef")]
shell = df[(df.Site_Name == "Shell Reef")]
faith = df[(df.Site_Name == "Faith Reef")]
shrimp = df[(df.Site_Name == "Shrimp Reef")]
hope = df[(df.Site_Name == "Hope Reef")]
UN_19_280 = df[(df.Site_Name == "U/N Reef 19-280")]
viper = df[(df.Site_Name == "Viper Reef")]
UN_18_132 = df[(df.Site_Name == "U/N Reef 18-132")]
tiger = df[(df.Site_Name == "Tiger Reef")]
cup = df[(df.Site_Name == "Cup Reef (North)")]
leopard = df[(df.Site_Name == "Leopard reef")]
jacqueline = df[(df.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'salt', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'salt', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'salt', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'salt', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'salt', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'salt', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'salt', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Salinity (PSU)", size= 15)
plt.title("Long-term Salinity", size = 20)

# add horizontal lines for thresholds 
plt.axhline(y=28.7, color='k', linestyle='--', label = 'Salinity Threshold: 28.7 PSU')

plt.legend(ncol = 3, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ### Coral Symbiont Chlorophyll

# %% [markdown]
# Note; several sites have been removed from the figure as they had no data recorded for the time period:
# * Burdekin river rivermouth
# * Burdekin river offshore
# * Tink Shoal
# * Morinda Shoal
# * Old Reef
# * Stanley Reef
# * (Big) Boradhurst reef
# * Charity reef
# * Faith Reef
# * Shrimp Reef
# * U/N 19-280

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df['Site_Name'].unique())
rivermouth = df[(df.Site_Name == "Burdekin river rivermouth")]
offshore = df[(df.Site_Name == "Burdekin river offshore")]
tink = df[(df.Site_Name == "Tink shoal")]
wilson = df[(df.Site_Name == "Wilson Shoal")]
morinda = df[(df.Site_Name == "Morinda Shoal")]
old = df[(df.Site_Name == "Old Reef")]
stanley = df[(df.Site_Name == "Stanley Reef")]
bowden = df[(df.Site_Name == "Bowden Reef")]
darley = df[(df.Site_Name == "Darley Reef")]
broadhurst = df[(df.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df[(df.Site_Name == "Charity reef")]
shell = df[(df.Site_Name == "Shell Reef")]
faith = df[(df.Site_Name == "Faith Reef")]
shrimp = df[(df.Site_Name == "Shrimp Reef")]
hope = df[(df.Site_Name == "Hope Reef")]
UN_19_280 = df[(df.Site_Name == "U/N Reef 19-280")]
viper = df[(df.Site_Name == "Viper Reef")]
UN_18_132 = df[(df.Site_Name == "U/N Reef 18-132")]
tiger = df[(df.Site_Name == "Tiger Reef")]
cup = df[(df.Site_Name == "Cup Reef (North)")]
leopard = df[(df.Site_Name == "Leopard reef")]
jacqueline = df[(df.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
# plt.plot('Aggregated_Date_Time', 'chloro', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
# plt.plot('Aggregated_Date_Time', 'chloro', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
# plt.plot('Aggregated_Date_Time', 'chloro', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'chloro', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
# plt.plot('Aggregated_Date_Time', 'chloro', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
# plt.plot('Aggregated_Date_Time', 'chloro', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
# plt.plot('Aggregated_Date_Time', 'chloro', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'chloro', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'chloro', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'chloro', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Coral Symbiont Chlorophyll (mg Chl m2)", size= 15)
plt.title("Long-term Coral Symbiont Chlorophyll", size = 20)

plt.legend(ncol = 3, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ## 2019 Flood Event

# %% [markdown]
# Filter out data for 2019 flood event:

# %%
# identify values that lie within date range selected (1/1/2019 - 01/05/2019)
mask = (df.Aggregated_Date_Time >= '2019-01-01') & (df.Aggregated_Date_Time <= '2019-04-01')
# create new object with these dates 
df_2019 = df.loc[mask]

# %% [markdown]
# ### Aragonite saturation state

# %%
# Assign each Site_Name to a new dataframe to plot: 
rivermouth = df_2019[(df_2019.Site_Name == "Burdekin river rivermouth")]
offshore = df_2019[(df_2019.Site_Name == "Burdekin river offshore")]
tink = df_2019[(df_2019.Site_Name == "Tink shoal")]
wilson = df_2019[(df_2019.Site_Name == "Wilson Shoal")]
morinda = df_2019[(df_2019.Site_Name == "Morinda Shoal")]
old = df_2019[(df_2019.Site_Name == "Old Reef")]
stanley = df_2019[(df_2019.Site_Name == "Stanley Reef")]
bowden = df_2019[(df_2019.Site_Name == "Bowden Reef")]
darley = df_2019[(df_2019.Site_Name == "Darley Reef")]
broadhurst = df_2019[(df_2019.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df_2019[(df_2019.Site_Name == "Charity reef")]
shell = df_2019[(df_2019.Site_Name == "Shell Reef")]
faith = df_2019[(df_2019.Site_Name == "Faith Reef")]
shrimp = df_2019[(df_2019.Site_Name == "Shrimp Reef")]
hope = df_2019[(df_2019.Site_Name == "Hope Reef")]
UN_19_280 = df_2019[(df_2019.Site_Name == "U/N Reef 19-280")]
viper = df_2019[(df_2019.Site_Name == "Viper Reef")]
UN_18_132 = df_2019[(df_2019.Site_Name == "U/N Reef 18-132")]
tiger = df_2019[(df_2019.Site_Name == "Tiger Reef")]
cup = df_2019[(df_2019.Site_Name == "Cup Reef (North)")]
leopard = df_2019[(df_2019.Site_Name == "Leopard reef")]
jacqueline = df_2019[(df_2019.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'omega', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'omega', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'omega', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'omega', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'omega', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'omega', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'omega', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'omega', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'omega', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Aragonite Saturation State (Ω)", size= 15)
plt.title("Long-term Aragonite Saturation State (Ω)", size = 20)
plt.ylim([1.25, 4])

# add horizontal lines for thresholds 
plt.axhline(y=2.82, color='k', linestyle='--', label = 'Ω Threshold: 2.82')


plt.legend(ncol = 2, loc = 'best', frameon = True, prop = {"size":11})

# %% [markdown]
# ### pH

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df_2019['Site_Name'].unique())
rivermouth = df_2019[(df_2019.Site_Name == "Burdekin river rivermouth")]
offshore = df_2019[(df_2019.Site_Name == "Burdekin river offshore")]
tink = df_2019[(df_2019.Site_Name == "Tink shoal")]
wilson = df_2019[(df_2019.Site_Name == "Wilson Shoal")]
morinda = df_2019[(df_2019.Site_Name == "Morinda Shoal")]
old = df_2019[(df_2019.Site_Name == "Old Reef")]
stanley = df_2019[(df_2019.Site_Name == "Stanley Reef")]
bowden = df_2019[(df_2019.Site_Name == "Bowden Reef")]
darley = df_2019[(df_2019.Site_Name == "Darley Reef")]
broadhurst = df_2019[(df_2019.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df_2019[(df_2019.Site_Name == "Charity reef")]
shell = df_2019[(df_2019.Site_Name == "Shell Reef")]
faith = df_2019[(df_2019.Site_Name == "Faith Reef")]
shrimp = df_2019[(df_2019.Site_Name == "Shrimp Reef")]
hope = df_2019[(df_2019.Site_Name == "Hope Reef")]
UN_19_280 = df_2019[(df_2019.Site_Name == "U/N Reef 19-280")]
viper = df_2019[(df_2019.Site_Name == "Viper Reef")]
UN_18_132 = df_2019[(df_2019.Site_Name == "U/N Reef 18-132")]
tiger = df_2019[(df_2019.Site_Name == "Tiger Reef")]
cup = df_2019[(df_2019.Site_Name == "Cup Reef (North)")]
leopard = df_2019[(df_2019.Site_Name == "Leopard reef")]
jacqueline = df_2019[(df_2019.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'pH', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'pH', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'pH', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'pH', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'pH', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'pH', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'pH', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'pH', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'pH', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("pH", size= 15)
plt.title("Long-term pH", size = 20)

plt.legend(ncol = 3, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ### Salinity

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df_2019['Site_Name'].unique())
rivermouth = df_2019[(df_2019.Site_Name == "Burdekin river rivermouth")]
offshore = df_2019[(df_2019.Site_Name == "Burdekin river offshore")]
tink = df_2019[(df_2019.Site_Name == "Tink shoal")]
wilson = df_2019[(df_2019.Site_Name == "Wilson Shoal")]
morinda = df_2019[(df_2019.Site_Name == "Morinda Shoal")]
old = df_2019[(df_2019.Site_Name == "Old Reef")]
stanley = df_2019[(df_2019.Site_Name == "Stanley Reef")]
bowden = df_2019[(df_2019.Site_Name == "Bowden Reef")]
darley = df_2019[(df_2019.Site_Name == "Darley Reef")]
broadhurst = df_2019[(df_2019.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df_2019[(df_2019.Site_Name == "Charity reef")]
shell = df_2019[(df_2019.Site_Name == "Shell Reef")]
faith = df_2019[(df_2019.Site_Name == "Faith Reef")]
shrimp = df_2019[(df_2019.Site_Name == "Shrimp Reef")]
hope = df_2019[(df_2019.Site_Name == "Hope Reef")]
UN_19_280 = df_2019[(df_2019.Site_Name == "U/N Reef 19-280")]
viper = df_2019[(df_2019.Site_Name == "Viper Reef")]
UN_18_132 = df_2019[(df_2019.Site_Name == "U/N Reef 18-132")]
tiger = df_2019[(df_2019.Site_Name == "Tiger Reef")]
cup = df_2019[(df_2019.Site_Name == "Cup Reef (North)")]
leopard = df_2019[(df_2019.Site_Name == "Leopard reef")]
jacqueline = df_2019[(df_2019.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
plt.plot('Aggregated_Date_Time', 'salt', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
plt.plot('Aggregated_Date_Time', 'salt', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
plt.plot('Aggregated_Date_Time', 'salt', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
plt.plot('Aggregated_Date_Time', 'salt', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
plt.plot('Aggregated_Date_Time', 'salt', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'salt', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'salt', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'salt', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'salt', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Salinity (PSU)", size= 15)
plt.title("Long-term Salinity", size = 20)

# add horizontal lines for thresholds 
plt.axhline(y=28.7, color='k', linestyle='--', label = 'Salinity Threshold: 28.7 PSU')

plt.legend(ncol = 2, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']

# %% [markdown]
# ### Coral Symbiont Chlorophyll

# %%
# Assign each Site_Name to a new dataframe to plot: 
print(df_2019['Site_Name'].unique())
rivermouth = df_2019[(df_2019.Site_Name == "Burdekin river rivermouth")]
offshore = df_2019[(df_2019.Site_Name == "Burdekin river offshore")]
tink = df_2019[(df_2019.Site_Name == "Tink shoal")]
wilson = df_2019[(df_2019.Site_Name == "Wilson Shoal")]
morinda = df_2019[(df_2019.Site_Name == "Morinda Shoal")]
old = df_2019[(df_2019.Site_Name == "Old Reef")]
stanley = df_2019[(df_2019.Site_Name == "Stanley Reef")]
bowden = df_2019[(df_2019.Site_Name == "Bowden Reef")]
darley = df_2019[(df_2019.Site_Name == "Darley Reef")]
broadhurst = df_2019[(df_2019.Site_Name == "(Big) Broadhurst Reef (No. 1)")]
charity = df_2019[(df_2019.Site_Name == "Charity reef")]
shell = df_2019[(df_2019.Site_Name == "Shell Reef")]
faith = df_2019[(df_2019.Site_Name == "Faith Reef")]
shrimp = df_2019[(df_2019.Site_Name == "Shrimp Reef")]
hope = df_2019[(df_2019.Site_Name == "Hope Reef")]
UN_19_280 = df_2019[(df_2019.Site_Name == "U/N Reef 19-280")]
viper = df_2019[(df_2019.Site_Name == "Viper Reef")]
UN_18_132 = df_2019[(df_2019.Site_Name == "U/N Reef 18-132")]
tiger = df_2019[(df_2019.Site_Name == "Tiger Reef")]
cup = df_2019[(df_2019.Site_Name == "Cup Reef (North)")]
leopard = df_2019[(df_2019.Site_Name == "Leopard reef")]
jacqueline = df_2019[(df_2019.Site_Name == "Jacqueline Reef")]

# make figure 
fig, ax = plt.subplots(figsize = (16, 8))

# Plot: 
# plt.plot('Aggregated_Date_Time', 'chloro', data = rivermouth, color = '#d00000', linewidth = 1, label = 'Rivermouth')
# plt.plot('Aggregated_Date_Time', 'chloro', data = offshore, color = '#FF0000', linewidth = 1, label = 'Offshore')
# plt.plot('Aggregated_Date_Time', 'chloro', data = tink, color = '#FFA200', linewidth = 1, label = 'Tink Shoal')
plt.plot('Aggregated_Date_Time', 'chloro', data = wilson, color = '#FFAE00', linewidth = 1, label = 'Wilson Shoal')
# plt.plot('Aggregated_Date_Time', 'chloro', data = morinda, color = '#FFB900', linewidth = 1, label = 'Morinda Shoal')
# plt.plot('Aggregated_Date_Time', 'chloro', data = old, color = '#FFC500', linewidth = 1, label = 'Old Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = stanley, color = '#FFD000', linewidth = 1, label = 'Stanley Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = bowden, color = '#FFDC00', linewidth = 1, label = 'Bowden Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = darley, color = '#FFE700', linewidth = 1, label = 'Darley Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = broadhurst, color = '#FFF300', linewidth = 1, label = '(Big) Broadhurst Reef (No. 1)')
# plt.plot('Aggregated_Date_Time', 'chloro', data = charity, color = '#FFFF00', linewidth = 1, label = 'Charity Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = shell, color = '#E7F317', linewidth = 1, label = 'Shell Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = faith, color = '#D0E72E', linewidth = 1, label = 'Faith Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = shrimp, color = '#B9DC45', linewidth = 1, label = 'Shrimp Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = hope, color = '#A2D05C', linewidth = 1, label = 'Hope Reef')
# plt.plot('Aggregated_Date_Time', 'chloro', data = UN_19_280, color = '#8BC573', linewidth = 1, label = 'U/N 19-280')
plt.plot('Aggregated_Date_Time', 'chloro', data = viper, color = '#73B98B', linewidth = 1, label = 'Viper Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = UN_18_132, color = '#5CAEA2', linewidth = 1, label = 'U/N 18-132')
plt.plot('Aggregated_Date_Time', 'chloro', data = tiger, color = '#45A2B9', linewidth = 1, label = 'Tiger Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = cup, color = '#2E97D0', linewidth = 1, label = 'Cup Reef (north)')
plt.plot('Aggregated_Date_Time', 'chloro', data = leopard, color = '#178BE7', linewidth = 1, label = 'Leopard Reef')
plt.plot('Aggregated_Date_Time', 'chloro', data = jacqueline, color = '#0080FF', linewidth = 1, label = 'Jacqueline Reef')

plt.xlabel("Year", size = 15)
plt.ylabel("Coral Symbiont Chlorophyll (mg Chl m2)", size= 15)
plt.title("Long-term Coral Symbiont Chlorophyll", size = 20)
plt.ylim([0.2, 1.02])

plt.legend(ncol = 2, loc = 'best', frameon = True, prop = {"size":11})
# Out:
# ['Old Reef' 'Faith Reef' 'Charity reef' 'Hope Reef' 'Tiger Reef'
#  'Leopard reef' 'Cup Reef (North)' 'Bowden Reef' 'U/N Reef 19-280'
#  'Burdekin river rivermouth' 'Burdekin river offshore' 'Tink shoal'
#  'Stanley Reef' 'Darley Reef' 'Shell Reef' 'Shrimp Reef' 'Viper Reef'
#  'U/N Reef 18-132' '(Big) Broadhurst Reef (No. 1)' 'Jacqueline Reef'
#  'Morinda Shoal' 'Wilson Shoal']
